# %%
import pandas as pd
import json
import requests
import numpy

# %%
df = pd.read_csv('Class_Codes.csv', encoding='cp1252')
df.sample(10)
# Out:
#      Course Code Course Number                                     Titles  \
# 2919         IST           280                       International Course
# 490          ART           531      Professional Practices in Visual Arts
# 3955         PNO           329                Performance Honors in Piano
# 2426         HOA           412                           The Gothic Spell
# 265          ANT           476                       Women, War and Peace
# 2437         HOA           440                               Women in Art
# 4210         PSY           334  Laboratory in Developmental Biopsychology
# 2758         HTW           321           Prevention in Addiction Services
# 2946         IST           442     Agile Project Management Methodologies
# 1920         ETS           450                          Reading Ethnicity
#
#             Day       Time                Location
# 2919     Friday  4:00-6:48                 Whitman
# 490      Monday  3:00-5:44  Heroy Geology Building
# ...

# %%
len(df)
# Out:
# 5227

# %%
#Course_Code = input('Enter a 3 letter class code: ').upper()
course = input('Enter a 3 letter code here: ')
for col in list(df):
    df[col] == course
    course_code = df[df[col] == course]
    print (course_code)
# Out:
# Enter a 3 letter code here: AAA
#   Course Code Course Number                                        Titles  \
# 0         AAA           101  Introduction to Asian/Asian-American Studies
# 1         AAA           200                               Selected Topics
# 2         AAA           300                               Selected Topics
# 3         AAA           307     Asian Americans and Social Stratification
# 4         AAA           380                          International Course
#
#          Day       Time           Location
# 0     Monday  1:00-3:00         Hinds Hall
# 1    Tuesday  2:00-4:00           Carnegie
# 2  Wednesday  3:00-5:00  Hall of Languages
# 3   Thursday  4:00-6:00   Physics Building
# 4     Friday  5:00-7:00               Falk
# Empty DataFrame
# Columns: [Course Code, Course Number, Titles, Day, Time, Location]
# Index: []
# Empty DataFrame
# Columns: [Course Code, Course Number, Titles, Day, Time, Location]
# Index: []
# Empty DataFrame
# ...

# %%
number = input('Enter a number code here: ')
for col in list(df):
    df[col] == number
    course_number = df[df[col] == number]
    print (course_number)
# Out:
# Enter a number code here: 123
# Empty DataFrame
# Columns: [Course Code, Course Number, Titles, Day, Time, Location]
# Index: []
#      Course Code Course Number                                   Titles  \
# 579          BIO           123                       General Biology II
# 3328         MAX           123  Critical Issues for the United States .
# 4048         PSC           123      Comparative Government and Politics
# 4349         REL           123                 Religious Auto/Biography
# 4509         SAS           123                 Religious Auto/Biography
#
#            Day       Time              Location
# 579     Friday  1:00-3:57               Whitman
# 3328  Thursday  2:00-4:21            Hinds Hall
# 4048  Thursday  3:00-5:38  Marshall Square Mall
# 4349    Friday  6:00-8:16               Whitman
# 4509    Friday  4:00-6:18     Crouse-Hinds Hall
# Empty DataFrame
# Columns: [Course Code, Course Number, Titles, Day, Time, Location]
# Index: []
# Empty DataFrame
# ...

# %%
df = pd.read_csv('Class_Codes.csv', encoding='cp1252')
df["Course"] = df["Course Code"] +' '+ df["Course Number"]
print (df)
# Out:
#      Course Code Course Number  \
# 0            AAA           101
# 1            AAA           200
# 2            AAA           300
# 3            AAA           307
# 4            AAA           380
# 5            AAS           112
# 6            AAS           138
# 7            AAS           200
# 8            AAS           202
# 9            AAS           206
# 10           AAS           207
# 11           AAS           213
# 12           AAS           214
# 13           AAS           231
# 14           AAS           232
# 15           AAS           233
# 16           AAS           234
# 17           AAS           235
# 18           AAS           241
# 19           AAS           254
# 20           AAS           290
# 21           AAS           300
# 22           AAS           302
# 23           AAS           303
# 24           AAS           304
# 25           AAS           305
# 26           AAS           306
# 27           AAS           307
# 28           AAS           309
# ...

# %%
df["Course"] = df["Course Code"] + ' '+ df["Course Number"] + ' '+ df["Titles"] + ' '+ df["Day"] + ' '+ df["Time"] + ' '+ df["Location"]
schedule = []
titles = df['Titles']
time = df['Time']
day = df['Day']
location = df['Location']
series = pd.Series['Class'[schedule], 'Titles'[titles], 'Day'[day], 'Time'[time], 'Location'[location]]

for Class in df["Course"]:
    Class = input('Enter a class to enroll in: ')
    schedule.append(Class)
    if Class == 'Done':
        break
        Final_Schedule
        

Final_Schedule = pd.DataFrame(series)
Final_Schedule
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-4a9b56bd9b37> in <module>
#       5 day = df['Day']
#       6 location = df['Location']
# ----> 7 series = pd.Series['Class'[schedule], 'Titles'[titles], 'Day'[day], 'Time'[time], 'Location'[location]]
#       8
#       9 for Class in df["Course"]:
#
# TypeError: string indices must be integers
